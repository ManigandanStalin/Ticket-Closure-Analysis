# %%
##import required packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
df=pd.read_csv('E:\Data Set\incident_event_log.csv')

# %%
df1=pd.DataFrame(df)

# %%
closed=df1[df1['incident_state']=='Closed']  #We need only data on closed tickets for our analysis. 
closed.head()
# Out:
#         number incident_state  active  reassignment_count  reopen_count  \
# 3   INC0000045         Closed   False                   0             0
# 12  INC0000047         Closed   False                   1             0
# 19  INC0000057         Closed   False                   0             0
# 23  INC0000060         Closed   False                   0             0
# 31  INC0000062         Closed   False                   1             0
#
#     sys_mod_count  made_sla    caller_id       opened_by        opened_at  \
# 3               4      True  Caller 2403    Opened by  8  29/2/2016 01:16
# 12              8      True  Caller 2403  Opened by  397  29/2/2016 04:40
# 19              6      True  Caller 4416    Opened by  8  29/2/2016 06:10
# 23              3      True  Caller 4491  Opened by  180  29/2/2016 06:38
# 31              7     False  Caller 3765  Opened by  180  29/2/2016 06:58
#
#     ... u_priority_confirmation         notify     problem_id rfc vendor  \
# ...

# %%
closed.drop(labels=['incident_state','active','sys_created_by','sys_created_at','sys_updated_by','sys_updated_at','contact_type','cmdb_ci','impact','urgency','knowledge','u_priority_confirmation','notify','rfc','vendor','caused_by','problem_id'], axis=1, inplace =True) 
#Feature selecting(Remove unwanted columns)

# %%
closed.head(5)
# Out:
#         number  reassignment_count  reopen_count  sys_mod_count  made_sla  \
# 3   INC0000045                   0             0              4      True
# 12  INC0000047                   1             0              8      True
# 19  INC0000057                   0             0              6      True
# 23  INC0000060                   0             0              3      True
# 31  INC0000062                   1             0              7     False
#
#       caller_id       opened_by        opened_at      location     category  \
# 3   Caller 2403    Opened by  8  29/2/2016 01:16  Location 143  Category 55
# 12  Caller 2403  Opened by  397  29/2/2016 04:40  Location 165  Category 40
# 19  Caller 4416    Opened by  8  29/2/2016 06:10  Location 204  Category 20
# 23  Caller 4491  Opened by  180  29/2/2016 06:38  Location 204   Category 9
# 31  Caller 3765  Opened by  180  29/2/2016 06:58   Location 93  Category 53
#
# ...

# %%
## replace special character with Null
for i in closed:
    closed[i]=closed[i].replace('?',np.nan)
    print(closed[i])
# Out:
# 3         INC0000045
# 12        INC0000047
# 19        INC0000057
# 23        INC0000060
# 31        INC0000062
#              ...
# 141695    INC0120304
# 141697    INC0120319
# 141703    INC0120495
# 141707    INC0120835
# 141711    INC0121064
# Name: number, Length: 24985, dtype: object
# 3         0
# 12        1
# 19        0
# 23        0
# 31        1
#          ..
# 141695    0
# 141697    0
# 141703    1
# 141707    1
# 141711    1
# Name: reassignment_count, Length: 24985, dtype: int64
# 3         0
# 12        0
# 19        0
# 23        0
# 31        0
#          ..
# 141695    0
# 141697    0
# 141703    0
# 141707    0
# 141711    0
# Name: reopen_count, Length: 24985, dtype: int64
# 3         4
# 12        8
# 19        6
# 23        3
# 31        7
#          ..
# 141695    2
# 141697    1
# 141703    5
# 141707    4
# 141711    3
# Name: sys_mod_count, Length: 24985, dtype: int64
# 3          True
# 12         True
# 19         True
# 23         True
# ...

# %%
closed.isna().sum()
# Out:
# number                   0
# reassignment_count       0
# reopen_count             0
# sys_mod_count            0
# made_sla                 0
# caller_id                3
# opened_by              715
# opened_at                0
# location                 8
# category                 8
# subcategory             10
# u_symptom             5856
# priority                 0
# assignment_group      2169
# assigned_to            729
# closed_code            107
# resolved_by            100
# resolved_at           1558
# closed_at                0
# dtype: int64

# %%
## Replace Null values with mode in all variable
for column in closed:
    closed[column].fillna(closed[column].mode()[0], inplace=True)

# %%
closed.isna().sum()
# Out:
# number                0
# reassignment_count    0
# reopen_count          0
# sys_mod_count         0
# made_sla              0
# caller_id             0
# opened_by             0
# opened_at             0
# location              0
# category              0
# subcategory           0
# u_symptom             0
# priority              0
# assignment_group      0
# assigned_to           0
# closed_code           0
# resolved_by           0
# resolved_at           0
# closed_at             0
# dtype: int64

# %%
closed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24985 entries, 0 to 24984
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   number              24985 non-null  object
#  1   reassignment_count  24985 non-null  int64
#  2   reopen_count        24985 non-null  int64
#  3   sys_mod_count       24985 non-null  int64
#  4   made_sla            24985 non-null  bool
#  5   caller_id           24985 non-null  object
#  6   opened_by           24985 non-null  object
#  7   opened_at           24985 non-null  object
#  8   location            24985 non-null  object
#  9   category            24985 non-null  object
#  10  subcategory         24985 non-null  object
#  11  u_symptom           24985 non-null  object
#  12  priority            24985 non-null  object
#  13  assignment_group    24985 non-null  object
#  14  assigned_to         24985 non-null  object
# ...

# %%
closed.to_excel('Notfinal.xlsx')

# %%
closed=pd.read_excel('Notfinal.xlsx')

# %%
closed.drop(labels='Unnamed: 0',axis=1,inplace=True)

# %%
closed.head()
# Out:
#        number  reassignment_count  reopen_count  sys_mod_count  made_sla  \
# 0  INC0000045                   0             0              4      True
# 1  INC0000047                   1             0              8      True
# 2  INC0000057                   0             0              6      True
# 3  INC0000060                   0             0              3      True
# 4  INC0000062                   1             0              7     False
#
#      caller_id       opened_by        opened_at      location     category  \
# 0  Caller 2403    Opened by  8  29/2/2016 01:16  Location 143  Category 55
# 1  Caller 2403  Opened by  397  29/2/2016 04:40  Location 165  Category 40
# 2  Caller 4416    Opened by  8  29/2/2016 06:10  Location 204  Category 20
# 3  Caller 4491  Opened by  180  29/2/2016 06:38  Location 204   Category 9
# 4  Caller 3765  Opened by  180  29/2/2016 06:58   Location 93  Category 53
#
# ...

# %%
for i in closed['caller_id']:
    closed['caller']=i[7:]
print(closed.head())
# Out:
#        number  reassignment_count  reopen_count  sys_mod_count  made_sla  \
# 0  INC0000045                   0             0              4      True
# 1  INC0000047                   1             0              8      True
# 2  INC0000057                   0             0              6      True
# 3  INC0000060                   0             0              3      True
# 4  INC0000062                   1             0              7     False
#
#      caller_id       opened_by        opened_at      location     category  \
# 0  Caller 2403    Opened by  8  29/2/2016 01:16  Location 143  Category 55
# 1  Caller 2403  Opened by  397  29/2/2016 04:40  Location 165  Category 40
# 2  Caller 4416    Opened by  8  29/2/2016 06:10  Location 204  Category 20
# 3  Caller 4491  Opened by  180  29/2/2016 06:38  Location 204   Category 9
# 4  Caller 3765  Opened by  180  29/2/2016 06:58   Location 93  Category 53
#
# ...

# %%
closed.drop(labels='caller',axis=1,inplace=True)

# %%
closed
# Out:
#            number  reassignment_count  reopen_count  sys_mod_count  made_sla  \
# 0      INC0000045                   0             0              4      True
# 1      INC0000047                   1             0              8      True
# 2      INC0000057                   0             0              6      True
# 3      INC0000060                   0             0              3      True
# 4      INC0000062                   1             0              7     False
# ...           ...                 ...           ...            ...       ...
# 24980  INC0120304                   0             0              2      True
# 24981  INC0120319                   0             0              1      True
# 24982  INC0120495                   1             0              5      True
# 24983  INC0120835                   1             0              4      True
# 24984  INC0121064                   1             0              3      True
#
# ...

# %%
closed.drop(labels='Caller',axis=1,inplace=True)

# %%
closed['caller_id']
# Out:
# 0        Caller 2403
# 1        Caller 2403
# 2        Caller 4416
# 3        Caller 4491
# 4        Caller 3765
#             ...
# 24980      Caller 90
# 24981    Caller 1899
# 24982     Caller 323
# 24983     Caller 116
# 24984     Caller 116
# Name: caller_id, Length: 24985, dtype: object

# %%
closed.to_excel('Final.xlsx')

# %%
l=[1,2,3,4,5]
l.remove(2)
l
# Out:
# [1, 3, 4, 5]
